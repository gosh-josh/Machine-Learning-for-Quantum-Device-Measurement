# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pickle
import random
import time,os
from tqdm import tqdm

# %%
cwd = os.getcwd()

data_set_list = []

for file in tqdm(os.listdir(cwd)):
    filename = os.fsdecode(file)
    if filename.endswith(".pkl"):
        print(filename)
        infile = open(filename,'rb')
        data_set = pickle.load(infile)
        data_set_list.append(data_set)
        infile.close()
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 1162.13it/s]
# measurement_9.pkl
# measurement_8.pkl
# measurement_7.pkl
# measurement_3.pkl
# measurement_6.pkl
# measurement_11.pkl
# measurement_4.pkl
# measurement_10.pkl
# measurement_1.pkl
# measurement_14.pkl
# measurement_13.pkl
# basel2.pkl
# measurement_17.pkl
# measurement_5.pkl
# measurement_16.pkl
# measurement_2.pkl
# measurement_12.pkl

# %%
cwd = os.getcwd()

data_set_list = []

for file in tqdm(os.listdir(cwd)):
    filename = os.fsdecode(file)
    if filename.endswith(".pkl"):
        print(filename)
        infile = open(filename,'rb')
        data_set = pickle.load(infile)
        data_set_list.append(data_set)
        infile.close()
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 4763.82it/s]
# measurement_9.pkl
# measurement_8.pkl
# measurement_7.pkl
# measurement_3.pkl
# measurement_6.pkl
# measurement_11.pkl
# measurement_4.pkl
# measurement_10.pkl
# measurement_1.pkl
# measurement_14.pkl
# measurement_13.pkl
# basel2.pkl
# measurement_17.pkl
# measurement_5.pkl
# measurement_16.pkl
# measurement_2.pkl
# measurement_12.pkl

# %%
i = 0
for data_set in data_set_list:
    if len(data_set) == 1:
        try:
            image = data_set['chan0']['data']
            np.save('data'+str(i),image)
            print('data'+str(i))
            i += 1
            plt.imshow(image)
            plt.show()
        except:
            print("ERROR")
            pass
'''    else:
        for i in range(len(data_set)):
            #print(data_set)
            print('Oi')
            try:
                image = data_set[i]['chan0']['data']
                np.save('data'+str(time.time()),image)
                print(i)
                plt.imshow(image)
                plt.show()
            except:
                print("ERROR 2 ")
                pass'''
# Out:
# data0
# data1
# data2
# data3
# data4
# data5
# data6
# data7
# data8
# ERROR
# data9
# data10
# data11
# data12
# data13
# data14
# data15
# ERROR
# data16
# '    else:\n        for i in range(len(data_set)):\n            #print(data_set)\n            print(\'Oi\')\n            try:\n                image = data_set[i][\'chan0\'][\'data\']\n                np.save(\'data\'+str(time.time()),image)\n                print(i)\n                plt.imshow(image)\n                plt.show()\n            except:\n                print("ERROR 2 ")\n                pass'

# %%
print(time.time())
# Out:
# 1583843373.9939065

# %%
data_set = np.load('useful/data11.npy')
data_set[:15,:5] = 1
plt.imshow(data_set)

# %%
for i in range(len(data_set)):
    try:
        image = data_set[i]['chan0']['data']
        print(i)
        plt.imshow(image)
        plt.show()
    except:
        print("No label",filename)
        pass
# Out:
# No label measurement_12.pkl

# %%
cwd = os.getcwd()

data_set_list = []

for file in tqdm(os.listdir(cwd+'/../basel2/')):
    filename = os.fsdecode(file)
    if filename.endswith(".pkl"):
        print(filename)
        infile = open(filename,'rb')
        data_set = pickle.load(infile)
        data_set_list.append(data_set)
        infile.close()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# /../basel2/measurement_29.pkl
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-9a10fa2ae935> in <module>
#       7     if filename.endswith(".pkl"):
#       8         print(filename)
# ----> 9         infile = open(filename,'rb')
#      10         data_set = pickle.load(infile)
#      11         data_set_list.append(data_set)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/../basel2/measurement_29.pkl'

# %%
filename = 'measurement_29.pkl'
infile = open('/../basel2/'+filename,'rb')
data_set = pickle.load(infile)
data_set_list.append(data_set)
infile.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-7ccbfe6e53be> in <module>
#       1 filename = 'measurement_29.pkl'
# ----> 2 infile = open('/../basel2/'+filename,'rb')
#       3 data_set = pickle.load(infile)
#       4 data_set_list.append(data_set)
#       5 infile.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/../basel2/measurement_29.pkl'
